# %%
import pandas as pd
import numpy as np
import matplotlib as plt
from sklearn.linear_model import LinearRegression

# %%
data =pd.read_csv('houses_to_rent.csv')

# %%
data.head()
# Out:
#    Unnamed: 0  city  area  rooms  bathroom  parking spaces floor     animal  \
# 0           0     1   240      3         3               4     -      acept
# 1           1     0    64      2         1               1    10      acept
# 2           2     1   443      5         5               4     3      acept
# 3           3     1    73      2         2               1    12      acept
# 4           4     1    19      1         1               0     -  not acept
#
#        furniture      hoa rent amount property tax fire insurance     total
# 0      furnished      R$0     R$8,000      R$1,000          R$121   R$9,121
# 1  not furnished    R$540       R$820        R$122           R$11   R$1,493
# 2      furnished  R$4,172     R$7,000      R$1,417           R$89  R$12,680
# 3  not furnished    R$700     R$1,250        R$150           R$16   R$2,116
# 4  not furnished      R$0     R$1,200         R$41           R$16   R$1,257

# %%
data.describe()
# Out:
#        Unnamed: 0         city          area        rooms     bathroom  \
# count  6080.00000  6080.000000   6080.000000  6080.000000  6080.000000
# mean   3039.50000     0.863322    151.143914     2.492599     2.341612
# std    1755.28915     0.343535    375.559485     1.129665     1.438860
# min       0.00000     0.000000     10.000000     1.000000     1.000000
# 25%    1519.75000     1.000000     58.000000     2.000000     1.000000
# 50%    3039.50000     1.000000    100.000000     3.000000     2.000000
# 75%    4559.25000     1.000000    200.000000     3.000000     3.000000
# max    6079.00000     1.000000  24606.000000    10.000000    10.000000
#
#        parking spaces
# count     6080.000000
# mean         1.756250
# std          1.611909
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          2.000000
# max         12.000000

# %%
data.tail()
# Out:
#       Unnamed: 0  city  area  rooms  bathroom  parking spaces floor  \
# 6075        6075     1    50      2         1               1     2
# 6076        6076     1    84      2         2               1    16
# 6077        6077     0    48      1         1               0    13
# 6078        6078     1   160      3         2               2     -
# 6079        6079     1    60      2         1               1     4
#
#          animal      furniture    hoa rent amount property tax fire insurance  \
# 6075      acept  not furnished  R$420     R$1,150          R$0           R$15
# 6076  not acept      furnished  R$768     R$2,900         R$63           R$37
# 6077      acept  not furnished  R$250       R$950         R$42           R$13
# 6078  not acept  not furnished    R$0     R$3,500        R$250           R$53
# 6079      acept      furnished  R$489     R$1,900          R$0           R$25
#
#         total
# 6075  R$1,585
# 6076  R$3,768
# 6077  R$1,255
# 6078  R$3,803
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6080 entries, 0 to 6079
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      6080 non-null   int64
#  1   city            6080 non-null   int64
#  2   area            6080 non-null   int64
#  3   rooms           6080 non-null   int64
#  4   bathroom        6080 non-null   int64
#  5   parking spaces  6080 non-null   int64
#  6   floor           6080 non-null   object
#  7   animal          6080 non-null   object
#  8   furniture       6080 non-null   object
#  9   hoa             6080 non-null   object
#  10  rent amount     6080 non-null   object
#  11  property tax    6080 non-null   object
#  12  fire insurance  6080 non-null   object
#  13  total           6080 non-null   object
# dtypes: int64(6), object(8)
# memory usage: 665.1+ KB

# %%
col_names = ['id', 'city', 'area', 'rooms','bathroom','parking spaces','floor','animal','furniture','hoa','rent amount'
             ,'property tax','fire insurance','total']

# %%
data.columns= col_names
data.columns
# Out:
# Index(['id', 'city', 'area', 'rooms', 'bathroom', 'parking spaces', 'floor',
#        'animal', 'furniture', 'hoa', 'rent amount', 'property tax',
#        'fire insurance', 'total'],
#       dtype='object')

# %%
data.drop('id',axis=1,inplace=True)
data.drop('floor',axis=1,inplace=True)
data.drop('hoa',axis=1,inplace=True)

data.drop('total',axis=1,inplace=True)
data.drop('property tax', axis=1 , inplace=True)

# %%
data.head()
# Out:
#    city  area  rooms  bathroom  parking spaces     animal      furniture  \
# 0     1   240      3         3               4      acept      furnished
# 1     0    64      2         1               1      acept  not furnished
# 2     1   443      5         5               4      acept      furnished
# 3     1    73      2         2               1      acept  not furnished
# 4     1    19      1         1               0  not acept  not furnished
#
#   rent amount fire insurance
# 0     R$8,000          R$121
# 1       R$820           R$11
# 2     R$7,000           R$89
# 3     R$1,250           R$16
# 4     R$1,200           R$16

# %%
#remove the R$ and , 
data['rent amount']= data['rent amount'].map(lambda i: int(i[2:].replace(',','')))
data['fire insurance']= data['fire insurance'].map(lambda i: int(i[2:].replace(',','')))

# %%
data
# Out:
#       city  area  rooms  bathroom  parking spaces     animal      furniture  \
# 0        1   240      3         3               4      acept      furnished
# 1        0    64      2         1               1      acept  not furnished
# 2        1   443      5         5               4      acept      furnished
# 3        1    73      2         2               1      acept  not furnished
# 4        1    19      1         1               0  not acept  not furnished
# ...    ...   ...    ...       ...             ...        ...            ...
# 6075     1    50      2         1               1      acept  not furnished
# 6076     1    84      2         2               1  not acept      furnished
# 6077     0    48      1         1               0      acept  not furnished
# 6078     1   160      3         2               2  not acept  not furnished
# 6079     1    60      2         1               1      acept      furnished
#
#       rent amount  fire insurance
# ...

# %%
from sklearn import preprocessing

# %%
le=preprocessing.LabelEncoder()
data['furniture']=le.fit_transform(data['furniture'])
data['animal']=le.fit_transform(data['animal'])

# %%
data
# Out:
#       city  area  rooms  bathroom  parking spaces  animal  furniture  \
# 0        1   240      3         3               4       0          0
# 1        0    64      2         1               1       0          1
# 2        1   443      5         5               4       0          0
# 3        1    73      2         2               1       0          1
# 4        1    19      1         1               0       1          1
# ...    ...   ...    ...       ...             ...     ...        ...
# 6075     1    50      2         1               1       0          1
# 6076     1    84      2         2               1       1          0
# 6077     0    48      1         1               0       0          1
# 6078     1   160      3         2               2       1          1
# 6079     1    60      2         1               1       0          0
#
#       rent amount  fire insurance
# 0            8000             121
# 1             820              11
# ...

# %%
data.isnull().sum()
# Out:
# city              0
# area              0
# rooms             0
# bathroom          0
# parking spaces    0
# animal            0
# furniture         0
# rent amount       0
# fire insurance    0
# dtype: int64

# %%
data.isna().sum()
# Out:
# city              0
# area              0
# rooms             0
# bathroom          0
# parking spaces    0
# animal            0
# furniture         0
# rent amount       0
# fire insurance    0
# dtype: int64

# %%
x=np.array(data.drop(['rent amount'],axis=1))
y=np.array(data['rent amount'])

# %%
x.shape
# Out:
# (6080, 8)

# %%
y.shape
# Out:
# (6080,)

# %%
x
# Out:
# array([[  1, 240,   3, ...,   0,   0, 121],
#        [  0,  64,   2, ...,   0,   1,  11],
#        [  1, 443,   5, ...,   0,   0,  89],
#        ...,
#        [  0,  48,   1, ...,   0,   1,  13],
#        [  1, 160,   3, ...,   1,   1,  53],
#        [  1,  60,   2, ...,   0,   0,  25]], dtype=int64)

# %%
y
# Out:
# array([8000,  820, 7000, ...,  950, 3500, 1900], dtype=int64)

# %%
from sklearn.model_selection import train_test_split

xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2,random_state=10)

# %%
xtrain.shape
# Out:
# (4864, 8)

# %%
xtest.shape
# Out:
# (1216, 8)

# %%
model=LinearRegression()
model.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
accuracy=model.score(xtest,ytest)
print(accuracy)
print(f'model coefficient:{model.coef_}')
print(f'model intercept:{model.intercept_}')
# Out:
# 0.9735925243269745
# model coefficient:[ 1.76723829e+02 -2.17066637e-01 -4.98523466e+01  8.92933300e+01
#  -5.21293735e+01  3.40429017e+01 -2.27704107e+02  7.11984672e+01]
# model intercept:298.9844971537541

# %%
test=model.predict(xtest)
print(test)
# Out:
# [1320.29699888 1579.51040055 2417.10428542 ...  970.46148656 5471.18754131
#  7137.72173301]

# %%
error=[]
for i,test in enumerate(test):
    error.append(ytest[i]-test)
    print(f'actual{ytest[i]} prediction:{int(test)} error :{int(error[i])}')
# Out:
# actual2426 prediction:1320 error :1105
# actual1200 prediction:1579 error :-379
# actual2300 prediction:2417 error :-117
# actual5930 prediction:6570 error :-640
# actual1100 prediction:1489 error :-389
# actual1200 prediction:1313 error :-113
# actual15000 prediction:16228 error :-1228
# actual1200 prediction:1356 error :-156
# actual7000 prediction:6583 error :416
# actual4675 prediction:5179 error :-504
# actual1305 prediction:1524 error :-219
# actual4500 prediction:4332 error :167
# actual8000 prediction:8710 error :-710
# actual2200 prediction:2148 error :51
# actual15000 prediction:13873 error :1126
# actual6500 prediction:6159 error :340
# actual1600 prediction:1474 error :125
# actual15000 prediction:13637 error :1362
# actual2200 prediction:2142 error :57
# actual2600 prediction:2981 error :-381
# actual1659 prediction:1816 error :-157
# actual1305 prediction:1524 error :-219
# actual6000 prediction:5647 error :352
# actual2975 prediction:2961 error :13
# ...
